# %%
import pandas as pd
import numpy as np

# %%
cars= pd.read_csv('Used_Cars.csv')

# %%
cars.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
cars.shape
# Out:
# (8123, 13)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8123 entries, 0 to 8122
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8123 non-null   object
#  1   year           8123 non-null   int64
#  2   selling_price  8123 non-null   int64
#  3   km_driven      8123 non-null   int64
#  4   fuel           8123 non-null   object
#  5   seller_type    8123 non-null   object
#  6   transmission   8123 non-null   object
#  7   owner          8123 non-null   object
#  8   mileage        7902 non-null   object
#  9   engine         7902 non-null   object
#  10  max_power      7908 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7902 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.1+ KB

# %%
cars['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
cars['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
cars['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
cars['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
cars['mileage'].unique()
# Out:
# array(['23.4 kmpl', '21.14 kmpl', '17.7 kmpl', '23.0 kmpl', '16.1 kmpl',
#        '20.14 kmpl', '17.3 km/kg', '23.59 kmpl', '20.0 kmpl',
#        '19.01 kmpl', '17.3 kmpl', '19.3 kmpl', nan, '18.9 kmpl',
#        '18.15 kmpl', '24.52 kmpl', '19.7 kmpl', '22.54 kmpl', '21.0 kmpl',
#        '25.5 kmpl', '26.59 kmpl', '21.5 kmpl', '20.3 kmpl', '21.4 kmpl',
#        '24.7 kmpl', '18.2 kmpl', '16.8 kmpl', '24.3 kmpl', '14.0 kmpl',
#        '18.6 kmpl', '33.44 km/kg', '23.95 kmpl', '17.0 kmpl',
#        '20.63 kmpl', '13.93 kmpl', '16.0 kmpl', '17.8 kmpl', '18.5 kmpl',
#        '12.55 kmpl', '12.99 kmpl', '14.8 kmpl', '13.5 kmpl', '26.0 kmpl',
#        '20.65 kmpl', '27.3 kmpl', '11.36 kmpl', '17.68 kmpl',
#        '14.28 kmpl', '18.53 kmpl', '14.84 kmpl', '21.12 kmpl',
#        '20.36 kmpl', '21.27 kmpl', '18.16 kmpl', '22.0 kmpl', '25.1 kmpl',
#        '20.51 kmpl', '21.66 kmpl', '25.2 kmpl', '22.9 kmpl', '16.02 kmpl',
#        '20.54 kmpl', '22.77 kmpl', '15.71 kmpl', '23.1 kmpl',
# ...

# %%
cars['engine'].unique()
# Out:
# array(['1248 CC', '1498 CC', '1497 CC', '1396 CC', '1298 CC', '1197 CC',
#        '1061 CC', '796 CC', '1364 CC', '1399 CC', '1461 CC', '993 CC',
#        nan, '1198 CC', '1199 CC', '998 CC', '1591 CC', '2179 CC',
#        '1368 CC', '2982 CC', '2494 CC', '2143 CC', '2477 CC', '1462 CC',
#        '2755 CC', '1968 CC', '1798 CC', '1196 CC', '1373 CC', '1598 CC',
#        '1998 CC', '1086 CC', '1194 CC', '1172 CC', '1405 CC', '1582 CC',
#        '999 CC', '2487 CC', '1999 CC', '3604 CC', '2987 CC', '1995 CC',
#        '1451 CC', '1969 CC', '2967 CC', '2497 CC', '1797 CC', '1991 CC',
#        '2362 CC', '1493 CC', '1599 CC', '1341 CC', '1794 CC', '799 CC',
#        '1193 CC', '2696 CC', '1495 CC', '1186 CC', '1047 CC', '2498 CC',
#        '2956 CC', '2523 CC', '1120 CC', '624 CC', '1496 CC', '1984 CC',
#        '2354 CC', '814 CC', '793 CC', '1799 CC', '936 CC', '1956 CC',
#        '1997 CC', '1499 CC', '1948 CC', '2997 CC', '2489 CC', '2499 CC',
# ...

# %%
cars['max_power'].unique()
# Out:
# array(['74 bhp', '103.52 bhp', '78 bhp', '90 bhp', '88.2 bhp',
#        '81.86 bhp', '57.5 bhp', '37 bhp', '67.1 bhp', '68.1 bhp',
#        '108.45 bhp', '60 bhp', '73.9 bhp', nan, '67 bhp', '82 bhp',
#        '88.5 bhp', '46.3 bhp', '88.73 bhp', '64.1 bhp', '98.6 bhp',
#        '88.8 bhp', '83.81 bhp', '83.1 bhp', '47.3 bhp', '73.8 bhp',
#        '34.2 bhp', '35 bhp', '81.83 bhp', '40.3 bhp', '121.3 bhp',
#        '138.03 bhp', '160.77 bhp', '117.3 bhp', '116.3 bhp', '83.14 bhp',
#        '67.05 bhp', '168.5 bhp', '100 bhp', '120.7 bhp', '98.63 bhp',
#        '175.56 bhp', '103.25 bhp', '171.5 bhp', '100.6 bhp', '174.33 bhp',
#        '187.74 bhp', '170 bhp', '78.9 bhp', '88.76 bhp', '86.8 bhp',
#        '108.495 bhp', '108.62 bhp', '93.7 bhp', '103.6 bhp', '98.59 bhp',
#        '189 bhp', '67.04 bhp', '68.05 bhp', '58.2 bhp', '82.85 bhp',
#        '81.80 bhp', '73 bhp', '120 bhp', '94.68 bhp', '160 bhp', '65 bhp',
# ...

# %%
cars['torque'].unique()
# Out:
# array(['190Nm@ 2000rpm', '250Nm@ 1500-2500rpm', '12.7@ 2,700(kgm@ rpm)',
#        '22.4 kgm at 1750-2750rpm', '11.5@ 4,500(kgm@ rpm)',
#        '113.75nm@ 4000rpm', '7.8@ 4,500(kgm@ rpm)', '59Nm@ 2500rpm',
#        '170Nm@ 1800-2400rpm', '160Nm@ 2000rpm', '248Nm@ 2250rpm',
#        '78Nm@ 4500rpm', nan, '84Nm@ 3500rpm', '115Nm@ 3500-3600rpm',
#        '200Nm@ 1750rpm', '62Nm@ 3000rpm', '219.7Nm@ 1500-2750rpm',
#        '114Nm@ 3500rpm', '115Nm@ 4000rpm', '69Nm@ 3500rpm',
#        '172.5Nm@ 1750rpm', '6.1kgm@ 3000rpm', '114.7Nm@ 4000rpm',
#        '60Nm@ 3500rpm', '90Nm@ 3500rpm', '151Nm@ 4850rpm',
#        '104Nm@ 4000rpm', '320Nm@ 1700-2700rpm', '250Nm@ 1750-2500rpm',
#        '145Nm@ 4600rpm', '146Nm@ 4800rpm', '343Nm@ 1400-3400rpm',
#        '200Nm@ 1400-3400rpm', '200Nm@ 1250-4000rpm',
#        '400Nm@ 2000-2500rpm', '138Nm@ 4400rpm', '360Nm@ 1200-3400rpm',
#        '200Nm@ 1200-3600rpm', '380Nm@ 1750-2500rpm', '173Nm@ 4000rpm',
# ...

# %%
cars['seats'].unique()
# Out:
# array([ 5.,  4., nan,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %% [markdown]
# # Quality
# -only first 3 words in name
# -take care of nan values and remove 'kmpl/kmkg' in mileage to convert dtype to float
# -take care of missing values and remove 'CC' in engine
# -take care of missing values and remove 'bhp' in max_power
# -take care of missing values and remove units and make a seperate column for rpm in torque
# -take care of nan and missing values, convert values to int in seats

# %%
cars=cars[~cars['engine'].isna()]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7902 entries, 0 to 8122
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7902 non-null   object
#  1   year           7902 non-null   int64
#  2   selling_price  7902 non-null   int64
#  3   km_driven      7902 non-null   int64
#  4   fuel           7902 non-null   object
#  5   seller_type    7902 non-null   object
#  6   transmission   7902 non-null   object
#  7   owner          7902 non-null   object
#  8   mileage        7902 non-null   object
#  9   engine         7902 non-null   object
#  10  max_power      7902 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7902 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 864.3+ KB

# %%
cars['name']=cars['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
cars.head()
# Out:
#                    name  year  selling_price  km_driven    fuel seller_type  \
# 0    Maruti Swift Dzire  2014         450000     145500  Diesel  Individual
# 1       Skoda Rapid 1.5  2014         370000     120000  Diesel  Individual
# 2  Honda City 2017-2020  2006         158000     140000  Petrol  Individual
# 3    Hyundai i20 Sportz  2010         225000     127000  Diesel  Individual
# 4      Maruti Swift VXI  2007         130000     120000  Petrol  Individual
#
#   transmission         owner     mileage   engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
cars=cars.reset_index(drop=True)

# %%
cars['mileage']=cars['mileage'].str.replace('kmpl',' ')

# %%
cars['mileage']=cars['mileage'].str.replace('km/kg',' ').astype(float)

# %%
cars['mileage'].head()
# Out:
# 0    23.40
# 1    21.14
# 2    17.70
# 3    23.00
# 4    16.10
# Name: mileage, dtype: float64

# %%
cars['engine']=cars['engine'].str.replace('CC',' ').astype(float)

# %%
cars['max_power'].unique()
# Out:
# array(['74 bhp', '103.52 bhp', '78 bhp', '90 bhp', '88.2 bhp',
#        '81.86 bhp', '57.5 bhp', '37 bhp', '67.1 bhp', '68.1 bhp',
#        '108.45 bhp', '60 bhp', '73.9 bhp', '67 bhp', '82 bhp', '88.5 bhp',
#        '46.3 bhp', '88.73 bhp', '64.1 bhp', '98.6 bhp', '88.8 bhp',
#        '83.81 bhp', '83.1 bhp', '47.3 bhp', '73.8 bhp', '34.2 bhp',
#        '35 bhp', '81.83 bhp', '40.3 bhp', '121.3 bhp', '138.03 bhp',
#        '160.77 bhp', '117.3 bhp', '116.3 bhp', '83.14 bhp', '67.05 bhp',
#        '168.5 bhp', '100 bhp', '120.7 bhp', '98.63 bhp', '175.56 bhp',
#        '103.25 bhp', '171.5 bhp', '100.6 bhp', '174.33 bhp', '187.74 bhp',
#        '170 bhp', '78.9 bhp', '88.76 bhp', '86.8 bhp', '108.495 bhp',
#        '108.62 bhp', '93.7 bhp', '103.6 bhp', '98.59 bhp', '189 bhp',
#        '67.04 bhp', '68.05 bhp', '58.2 bhp', '82.85 bhp', '81.80 bhp',
#        '73 bhp', '120 bhp', '94.68 bhp', '160 bhp', '65 bhp', '155 bhp',
# ...

# %%
cars['max_power']=cars['max_power'].str.replace('bhp','')

# %%
cars['seats']=cars['seats'].astype(int)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7902 entries, 0 to 7901
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7902 non-null   object
#  1   year           7902 non-null   int64
#  2   selling_price  7902 non-null   int64
#  3   km_driven      7902 non-null   int64
#  4   fuel           7902 non-null   object
#  5   seller_type    7902 non-null   object
#  6   transmission   7902 non-null   object
#  7   owner          7902 non-null   object
#  8   mileage        7902 non-null   float64
#  9   engine         7902 non-null   float64
#  10  max_power      7902 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7902 non-null   int32
# dtypes: float64(2), int32(1), int64(3), object(7)
# memory usage: 771.8+ KB

# %%
cars.head()
# Out:
#                    name  year  selling_price  km_driven    fuel seller_type  \
# 0    Maruti Swift Dzire  2014         450000     145500  Diesel  Individual
# 1       Skoda Rapid 1.5  2014         370000     120000  Diesel  Individual
# 2  Honda City 2017-2020  2006         158000     140000  Petrol  Individual
# 3    Hyundai i20 Sportz  2010         225000     127000  Diesel  Individual
# 4      Maruti Swift VXI  2007         130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine max_power  \
# 0       Manual   First Owner    23.40  1248.0       74
# 1       Manual  Second Owner    21.14  1498.0   103.52
# 2       Manual   Third Owner    17.70  1497.0       78
# 3       Manual   First Owner    23.00  1396.0       90
# 4       Manual   First Owner    16.10  1298.0     88.2
#
#                      torque  seats
# 0            190Nm@ 2000rpm      5
# 1       250Nm@ 1500-2500rpm      5
# 2     12.7@ 2,700(kgm@ rpm)      5
# ...

# %%
cars['torque'].str.split('@')
# Out:
# 0                   [190Nm,  2000rpm]
# 1              [250Nm,  1500-2500rpm]
# 2           [12.7,  2,700(kgm,  rpm)]
# 3          [22.4 kgm at 1750-2750rpm]
# 4           [11.5,  4,500(kgm,  rpm)]
#                     ...
# 7897              [113.7Nm,  4000rpm]
# 7898    [24,  1,900-2,750(kgm,  rpm)]
# 7899                [190Nm,  2000rpm]
# 7900           [140Nm,  1800-3000rpm]
# 7901           [140Nm,  1800-3000rpm]
# Name: torque, Length: 7902, dtype: object

# %%
cars = cars.drop('torque',1)
# Out:
# C:\Users\Gokul\AppData\Local\Temp/ipykernel_18336/410408976.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   cars = cars.drop('torque',1)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7902 entries, 0 to 7901
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7902 non-null   object
#  1   year           7902 non-null   int64
#  2   selling_price  7902 non-null   int64
#  3   km_driven      7902 non-null   int64
#  4   fuel           7902 non-null   object
#  5   seller_type    7902 non-null   object
#  6   transmission   7902 non-null   object
#  7   owner          7902 non-null   object
#  8   mileage        7902 non-null   float64
#  9   engine         7902 non-null   float64
#  10  max_power      7902 non-null   object
#  11  seats          7902 non-null   int32
# dtypes: float64(2), int32(1), int64(3), object(6)
# memory usage: 710.1+ KB

# %%
cars['max_power'] = pd.to_numeric(cars['max_power'],errors = 'coerce')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7902 entries, 0 to 7901
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7902 non-null   object
#  1   year           7902 non-null   int64
#  2   selling_price  7902 non-null   int64
#  3   km_driven      7902 non-null   int64
#  4   fuel           7902 non-null   object
#  5   seller_type    7902 non-null   object
#  6   transmission   7902 non-null   object
#  7   owner          7902 non-null   object
#  8   mileage        7902 non-null   float64
#  9   engine         7902 non-null   float64
#  10  max_power      7901 non-null   float64
#  11  seats          7902 non-null   int32
# dtypes: float64(3), int32(1), int64(3), object(5)
# memory usage: 710.1+ KB

# %%
cars.to_csv('cleaned_cars.csv')

# %%
cars[cars['max_power'].isnull()]
# Out:
#                  name  year  selling_price  km_driven fuel seller_type  \
# 4792  Maruti Omni CNG  2000          80000     100000  CNG  Individual
#
#      transmission         owner  mileage  engine  max_power  seats
# 4792       Manual  Second Owner     10.9   796.0        NaN      8

# %%
cars['max_power'][4795]=cars['max_power'].mean()
# Out:
# C:\Users\Gokul\AppData\Local\Temp/ipykernel_18336/2923900804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['max_power'][4795]=cars['max_power'].mean()

# %%
cars['max_power'].isnull().sum()
# Out:
# 1

# %% [markdown]
# ## Model

# %%
X = cars.drop(columns="selling_price")

# %%
y = cars['selling_price']

# %%
X
# Out:
#                       name  year  km_driven    fuel seller_type transmission  \
# 0       Maruti Swift Dzire  2014     145500  Diesel  Individual       Manual
# 1          Skoda Rapid 1.5  2014     120000  Diesel  Individual       Manual
# 2     Honda City 2017-2020  2006     140000  Petrol  Individual       Manual
# 3       Hyundai i20 Sportz  2010     127000  Diesel  Individual       Manual
# 4         Maruti Swift VXI  2007     120000  Petrol  Individual       Manual
# ...                    ...   ...        ...     ...         ...          ...
# 7897     Hyundai i20 Magna  2013     110000  Petrol  Individual       Manual
# 7898    Hyundai Verna CRDi  2007     119000  Diesel  Individual       Manual
# 7899    Maruti Swift Dzire  2009     120000  Diesel  Individual       Manual
# 7900       Tata Indigo CR4  2013      25000  Diesel  Individual       Manual
# 7901       Tata Indigo CR4  2013      25000  Diesel  Individual       Manual
#
# ...

# %%
y.shape
# Out:
# (7902,)

# %% [markdown]
# ## Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# ## Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','fuel','seller_type','transmission','owner']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 35', 'Audi A3 40', 'Audi A4 1.8', 'Audi A4 2.0',
#         'Audi A4 35', 'Audi A6 2.0', 'Audi A6 35', 'Audi Q3 2.0',
#         'Audi Q3 35', 'Audi Q5 2.0', 'Audi Q5 3.0', 'Audi Q5 35TDI',
#         'Audi Q5 45', 'Audi Q7 3.0', 'Audi Q7 35', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 6 Series', 'BMW 7 Series', 'BMW X1 sDrive',
#         'BMW X1 sDrive20d', 'BMW X1 sDrive20i', 'BMW X3 xDrive20d',
#         'BMW X4 M', 'BMW X5 3.0d', 'BMW X6 xDrive30d', 'BMW X7 xDrive',
#         'Chevrolet Aveo 1.4', 'Chevrolet Aveo U-VA',
#         'Chevrolet Beat Diesel', 'Chevrolet Beat LS', 'Chevrolet Beat LT',
#         'Chevrolet Captiva 2.2', 'Chevrolet Captiva LT',
#         'Chevrolet Cruze LT', 'Chevrolet Cruze LTZ', 'Chevrolet Enjoy 1.3',
#         'Chevrolet Enjoy 1.4', 'Chevrolet Enjoy Petrol',
#         'Chevrolet Enjoy TCDi', 'Chevrolet Optra 1.6',
#         'Chevrolet Optra Magnum', 'Chevrolet Sail 1.2',
#         'Chevrolet Sail 1.3', 'Chevrolet Sail Hatchback',
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','fuel','seller_type','transmission','owner']),
                                    remainder='passthrough')

# %% [markdown]
# ## Linear Regression Model

# %%
lr=LinearRegression()

# %% [markdown]
# ## Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# ## Fitting the model

# %%
X_train.isnull().sum()
# Out:
# name            0
# year            0
# km_driven       0
# fuel            0
# seller_type     0
# transmission    0
# owner           0
# mileage         0
# engine          0
# max_power       1
# seats           0
# dtype: int64

# %%
X_train=X_train.reset_index(drop=True)
X_train
# Out:
#                      name  year  km_driven    fuel       seller_type  \
# 0        Maruti Swift ZXI  2018      20000  Petrol        Individual
# 1      Hyundai i10 Sportz  2010      70000  Petrol        Individual
# 2           Maruti Eeco 7  2017      35000  Petrol        Individual
# 3     Jaguar XE 2016-2019  2017       9000  Diesel            Dealer
# 4         Skoda Rapid 1.6  2016      11000  Petrol            Dealer
# ...                   ...   ...        ...     ...               ...
# 7106      Maruti Omni MPI  2016      40000  Petrol        Individual
# 7107    Toyota Innova 2.5  2013      79328  Diesel  Trustmark Dealer
# 7108      Maruti Alto LXi  2010      80000  Petrol        Individual
# 7109     Toyota Camry 2.5  2016      68089  Petrol  Trustmark Dealer
# 7110      Maruti Alto K10  2012      80000  Petrol        Individual
#
#      transmission         owner  mileage  engine  max_power  seats
# 0          Manual   First Owner    22.00  1197.0       81.8      5
# ...

# %%
y_train=y_train.reset_index(drop=True)
y_train
# Out:
# 0        720000
# 1        200000
# 2        350000
# 3       2625000
# 4        645000
#          ...
# 7106     240000
# 7107     750000
# 7108     140000
# 7109    2000000
# 7110     110000
# Name: selling_price, Length: 7111, dtype: int64

# %%
y_test=y_test.reset_index(drop=True)
y_test
# Out:
# 0      800000
# 1      600000
# 2      215000
# 3      170000
# 4      265000
#         ...
# 786    300000
# 787    550000
# 788    240000
# 789    500000
# 790    200000
# Name: selling_price, Length: 791, dtype: int64

# %%
X_test=X_test.reset_index(drop=True)
X_test
# Out:
#                     name  year  km_driven    fuel seller_type transmission  \
# 0      Ford EcoSport 1.5  2017      60000  Diesel  Individual       Manual
# 1       Maruti Swift AMT  2018      69779  Petrol      Dealer    Automatic
# 2        Maruti Alto LXi  2011      50000  Petrol  Individual       Manual
# 3       Hyundai Verna Xi  2006     110000  Petrol  Individual       Manual
# 4      Hyundai EON Magna  2017     100000  Petrol  Individual       Manual
# ..                   ...   ...        ...     ...         ...          ...
# 786   Hyundai i10 Sportz  2014      65000  Petrol  Individual       Manual
# 787  Volkswagen Polo 1.5  2015      90000  Diesel  Individual       Manual
# 788      Maruti Alto K10  2014      80000  Petrol  Individual       Manual
# 789     Mahindra KUV 100  2018      60000  Petrol  Individual       Manual
# 790      Maruti Ritz VDi  2009     120000  Diesel  Individual       Manual
#
#                     owner  mileage  engine  max_power  seats
# ...

# %%
pipe.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18336/3565212875.py in <module>
# ----> 1 pipe.fit(X_train,y_train)
#
# D:\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ...

# %%
y_pred=pipe.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18336/941590274.py in <module>
# ----> 1 y_pred=pipe.predict(X_test)
#
# D:\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# D:\Anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     417         for _, name, transform in self._iter(with_final=False):
#     418             Xt = transform.transform(Xt)
# --> 419         return self.steps[-1][-1].predict(Xt, **predict_params)
#     420
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9633254016147091

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 455

# %%
scores[np.argmax(scores)]
# Out:
# 0.9805506128865021

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Swift Dzire',2019,10000,'Petrol','Individual','Manual','First Owner',18,1200,80,5]], columns=['name','year','km_driven','fuel','seller_type','transmission','owner','mileage','engine','max_power','seats']))
# Out:
# array([673739.57871152])
